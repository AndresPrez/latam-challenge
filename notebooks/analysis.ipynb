# %%
# load dataset
import pandas as pd
dataset = pd.read_csv('../data/dataset.csv')
dataset.head()
# Out:
#                Fecha-I Vlo-I Ori-I Des-I Emp-I              Fecha-O Vlo-O  \
# 0  2017-01-01 23:30:00   226  SCEL  KMIA   AAL  2017-01-01 23:33:00   226
# 1  2017-01-02 23:30:00   226  SCEL  KMIA   AAL  2017-01-02 23:39:00   226
# 2  2017-01-03 23:30:00   226  SCEL  KMIA   AAL  2017-01-03 23:39:00   226
# 3  2017-01-04 23:30:00   226  SCEL  KMIA   AAL  2017-01-04 23:33:00   226
# 4  2017-01-05 23:30:00   226  SCEL  KMIA   AAL  2017-01-05 23:28:00   226
#
#   Ori-O Des-O Emp-O  DIA  MES   AÑO     DIANOM TIPOVUELO              OPERA  \
# 0  SCEL  KMIA   AAL    1    1  2017    Domingo         I  American Airlines
# 1  SCEL  KMIA   AAL    2    1  2017      Lunes         I  American Airlines
# 2  SCEL  KMIA   AAL    3    1  2017     Martes         I  American Airlines
# 3  SCEL  KMIA   AAL    4    1  2017  Miercoles         I  American Airlines
# 4  SCEL  KMIA   AAL    5    1  2017     Jueves         I  American Airlines
#
#    SIGLAORI SIGLADES
# 0  Santiago    Miami
# ...

# %%
# Out:
# <style type="text/css">
# #T_bf497_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bf497">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf497_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bf497_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf497_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf497_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_bf497_row0_col1" class="data row0 col1" >3292</td>
#     </tr>
#     <tr>
#       <th id="T_bf497_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bf497_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bf497_row1_col1" class="data row1 col1" >MES</td>
#     </tr>
#     <tr>
#       <th id="T_bf497_level0_row2" class="row_heading level0 row2" >2</th>
# ...
